# %%
 # make bar graph of top 5 features in the data  
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
# file download 
file = "Desktop/worldbank_data_postprocssed.txt" 
df=pd.read_csv(file) 
df.head()
# Out:
#    SP.RUR.TOTL.ZG  SP.DYN.LE00.MA.IN  SP.DYN.CDRT.IN  SE.SEC.AGES  \
# 0        2.245444          57.416857       10.326000         12.0
# 1        0.279143          69.619952        4.827000         12.0
# 2        0.778734          79.338095        6.647619         12.0
# 3       -0.346674          44.823143       17.551429         13.0
# 4       -1.250894          67.880952       13.414286         11.0
#
#    TT.PRI.MRCH.XD.WD  TM.VAL.MRCH.HI.ZS  SP.URB.TOTL.IN.ZS   SP.POP.TOTL  \
# 0         129.377917          31.947939          47.971762  3.887553e+06
# 1         157.141001          61.037195          78.231571  6.130843e+06
# 2         114.091846          60.336391          14.558190  3.597138e+04
# 3          84.337897          12.531720          24.554095  2.036223e+06
# 4          98.158540          67.521595          67.051048  3.113615e+06
#
#    NY.ADJ.AEDU.GN.ZS  TM.VAL.MRCH.WL.CD  ...  TM.UVI.MRCH.XD.WD  \
# ...

# %%
# SP.RUR.TOTL.ZG 
df = df.sort_values("SP.RUR.TOTL.ZG")
plt.bar(df['Country'], df['SP.RUR.TOTL.ZG']) 
plt.title=('Country VS SP.RUR.TOTL.ZG ') 
plt.xlabel('Country', fontsize=8)
plt.xticks(rotation=90)
plt.ylabel('SP.RUR.TOTL.ZG')
plt.gcf().set_size_inches(40, 6)
plt.show()

# %%
#SP.DYN.LE00.MA.IN 
df = df.sort_values("SP.DYN.LE00.MA.IN")
plt.bar(df['Country'], df['SP.DYN.LE00.MA.IN']) 
plt.title=('Country VS SP.DYN.LE00.MA.IN ') 
plt.xlabel('Country', fontsize=8)
plt.xticks(rotation=90)
plt.ylabel('SP.DYN.LE00.MA.IN')
plt.gcf().set_size_inches(40, 6)
plt.show()

# %%
#SP.DYN.CDRT.IN 
df = df.sort_values("SP.DYN.CDRT.IN")
plt.bar(df['Country'], df['SP.DYN.CDRT.IN']) 
plt.title=('Country VS SP.DYN.CDRT.IN') 
plt.xlabel('Country', fontsize=8)
plt.xticks(rotation=90)
plt.ylabel('SP.DYN.CDRT.IN')
plt.gcf().set_size_inches(40, 6)
plt.show()

# %%
#SE.SEC.AGES 
df = df.sort_values("SE.SEC.AGES")
plt.bar(df['Country'], df['SE.SEC.AGES']) 
plt.title=('Country VS SE.SEC.AGES ') 
plt.xlabel('Country', fontsize=8)
plt.xticks(rotation=90)
plt.ylabel('SE.SEC.AGES')
plt.gcf().set_size_inches(40, 6)
plt.show()

# %%
#TT.PRI.MRCH.XD.WD 
df = df.sort_values("TT.PRI.MRCH.XD.WD")
plt.bar(df['Country'], df['TT.PRI.MRCH.XD.WD']) 
plt.title=('Country VS TT.PRI.MRCH.XD.WD') 
plt.xlabel('Country', fontsize=12)
plt.xticks(rotation=90)
plt.ylabel('TT.PRI.MRCH.XD.WD')
plt.gcf().set_size_inches(40, 6)
plt.show()
